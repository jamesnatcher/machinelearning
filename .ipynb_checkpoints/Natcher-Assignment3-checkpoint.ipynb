# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import numpy as np
import os
import pickle
import pandas as pd

files_path = r"G:\Spring2022\CS 415\Assignment 3\NonKaggleData\cifar-10-batches-py"
meta_path = r"G:\Spring2022\CS 415\Assignment 3\NonKaggleData\cifar-10-batches-py\batches.meta"

print(tf.__version__)
tf.test.gpu_device_name()
# Out:
# 2.8.0
# ''

# %%
os.chdir(files_path)
os.getcwd()
# Out:
# 'G:\\Spring2022\\CS 415\\Assignment 3\\NonKaggleData\\cifar-10-batches-py'

# %%
directory_contents = os.listdir(os.getcwd())
directory_contents.remove('batches.meta')
directory_contents.remove('readme.html')
print(directory_contents)
# Out:
# ['data_batch_1', 'data_batch_2', 'data_batch_3', 'data_batch_4', 'data_batch_5', 'test_batch']

# %%
class_names = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]
print(class_names)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
def unpickle(file):
    with open(file, 'rb') as fo:
        thing = pickle.load(fo, encoding='bytes')
    return thing

# %%
train_labels = []
train_data = None

test_labels = []
test_data = None

# %%
for batch in directory_contents:
    
    batch_temp = unpickle(batch)
    
    if batch != 'test_batch':
    
        if batch == 'data_batch_1':
            train_data = batch_temp[b'data']
        else:
            train_data = np.vstack((train_data, batch_temp[b'data']))
    
        train_labels += batch_temp[b'labels']
    else:
        test_labels = batch_temp[b'labels']
        test_data = batch_temp[b'data']
                                                      

            

meta_data = unpickle(meta_path)
meta_data.pop(b'num_cases_per_batch')
meta_data.pop(b'num_vis')
# Out:
# 3072

# %%
print(meta_data)
# Out:
# {b'label_names': [b'airplane', b'automobile', b'bird', b'cat', b'deer', b'dog', b'frog', b'horse', b'ship', b'truck']}

# %%
print(len(train_labels))
print(train_labels)
# Out:
# 50000
# ...

# %%
print(len(test_labels))
print(test_labels)
# Out:
# 10000
# ...

# %%
print(train_data.shape)
print(len(train_data))
print(train_data)
# Out:
# (50000, 3072)
# 50000
# [[ 59  43  50 ... 140  84  72]
#  [154 126 105 ... 139 142 144]
#  [255 253 253 ...  83  83  84]
#  ...
#  [ 35  40  42 ...  77  66  50]
#  [189 186 185 ... 169 171 171]
#  [229 236 234 ... 173 162 161]]

# %%
print(test_data.shape)
print(len(test_data))
print(test_data)
# Out:
# (10000, 3072)
# 10000
# [[158 159 165 ... 124 129 110]
#  [235 231 232 ... 178 191 199]
#  [158 158 139 ...   8   3   7]
#  ...
#  [ 20  19  15 ...  50  53  47]
#  [ 25  15  23 ...  80  81  80]
#  [ 73  98  99 ...  94  58  26]]

# %%
# This section originally serached for the maximum and minimum of the data in my old code.
# The section is commented out due to time it takes to run it, but the result is displayed in bottom comments.

#minimum = batch_group[0][b'data'][0][0]
#maximum = batch_group[0][b'data'][0][0]
#for batch in batch_group:
#    for line in batch[b'data']:
#        for num in line:
#            if num > maximum:
#                maximum = num
#            if num < minimum:
#                minimum = num
#print(minimum) == 0
#print(maximum) == 255

# %%
#for batch in batch_group:
    #batch[b'data'] = batch[b'data'] / 255

for i in range(len(train_data)):
    train_data[i] = train_data[i].astype(np.float32)

for i in range(len(test_data)):
    test_data[i] = test_data[i].astype(np.float32)

for i in range(len(train_data)):
    
    #np.divide(train_data[i], 255.)
    train_data[i] = train_data[i] / 255.0

for i in range(len(test_data)):
    #np.divide(test_data[i], 255.)
    test_data[i] = test_data[i] / 255.0

# %%
train_data = train_data.reshape(len(train_data), 3, 32, 32)
test_data = test_data.reshape(len(test_data), 3, 32, 32)

# %%
print(train_data.shape)
print(test_data.shape)
# Out:
# (50000, 3, 32, 32)
# (10000, 3, 32, 32)

# %%
train_data = np.rollaxis(train_data, 1, 4)
test_data = np.rollaxis(test_data, 1, 4)

# %%
print(train_data.shape)
print(test_data.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
print(len(train_data))
print(train_data[0][0][0])
print(type(train_data[0][0][0][0]))
# Out:
# 50000
# [0 0 0]
# <class 'numpy.uint8'>

# %%
print(len(test_data))
print(test_data[0][0][0])
# Out:
# 10000
# [0 0 0]

# %%
labels = batch_group[0][b'labels']
data = batch_group[0][b'data']

df_train = pd.DataFrame([(labels, data) for labels, data in zip(labels, data)],
                  columns=['Labels','Data'])

labels = batch_group[5][b'labels']
data = batch_group[5][b'data']

df_test = pd.DataFrame([(labels, data) for labels, data in zip(labels, data)],
                  columns=['Labels','Data'])

for batch in batch_group[1:-1]:
    labels_for = batch[b'labels']
    data_for = batch[b'data']
    
    df2 = pd.DataFrame([(labels_for, data_for) for labels_for, data_for in zip(labels_for, data_for)],
                  columns=['Labels','Data'])
    
    df_train = pd.concat([df_train, df2], ignore_index = True, axis = 0)

# %%
df_train

# %%
df_test

# %%
cnn = models.Sequential()

# %%
cnn.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Conv2D(64, (3, 3), activation='relu'))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
cnn.summary()

# %%
X_train.shape
